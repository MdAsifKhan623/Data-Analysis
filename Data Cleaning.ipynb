# %%
import numpy as np 
import pandas as pd

# %%
df=pd.read_csv('Banking.csv')

# %%
df.head()
# Out:
#     age          job  marital          education  default housing loan  \
# 0  44.0  blue-collar  married           basic.4y  unknown     yes   no
# 1  53.0   technician  married            unknown       no      no   no
# 2  28.0   management   single  university.degree       no     yes   no
# 3  39.0     services  married        high.school       no      no   no
# 4  55.0      retired  married           basic.4y       no     yes   no
#
#     contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  cellular   aug         thu  ...         1    999         0  nonexistent
# 1  cellular   nov         fri  ...         1    999         0  nonexistent
# 2  cellular   jun         thu  ...         3      6         2      success
# 3  cellular   apr         fri  ...         2    999         0  nonexistent
# 4  cellular   aug         fri  ...         1      3         1      success
#
#   emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  nr_employed  y
# ...

# %%
df.shape
# Out:
# (41199, 21)

# %%
df.isna().sum()
# Out:
# age               2
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           6
# month             0
# day_of_week       0
# duration          7
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
df[df['age'].isnull()]
# Out:
#        age         job  marital            education default housing loan  \
# 41197  NaN  technician  married  professional.course      no      no    n
# 41198  NaN     student   single          high.school      no      no    n
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 41197  telephone   oct         tue  ...         2    999         0
# 41198  telephone   may         fri  ...         4    999         0
#
#           poutcome emp_var_rate  cons_price_idx  cons_conf_idx  euribor3m  \
# 41197  nonexistent         -3.4          92.431          -26.9      0.742
# 41198  nonexistent          1.1          93.994          -36.4      4.859
#
#        nr_employed  y
# 41197       5017.5  0
# 41198       5191.0  0
#
# [2 rows x 21 columns]

# %%
mean_age=df.age.mean()

# %%
print("mean age:",mean_age)
# Out:
# mean age: 40.023812413525256

# %%
df.age.fillna(mean_age,inplace=True)

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           6
# month             0
# day_of_week       0
# duration          7
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
df[df['duration'].isnull()]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp_var_rate, cons_price_idx, cons_conf_idx, euribor3m, nr_employed, y]
# Index: []
#
# [0 rows x 21 columns]

# %%
df['duration']
# Out:
# 0        210.0
# 1        138.0
# 2        339.0
# 3        185.0
# 4        137.0
#          ...
# 41194    222.0
# 41195      NaN
# 41196     62.0
# 41197    200.0
# 41198    112.0
# Name: duration, Length: 41199, dtype: float64

# %%
medianDuration=df.duration.median()
print(medianDuration)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     124             else:
# --> 125                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     126
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna, mask)
#     590     if not is_float_dtype(values):
# --> 591         values = values.astype("f8")
#     592         if mask is not None:
#
# ValueError: could not convert string to float: 'cellular'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
df.duration.fillna(medianDuration,inplace=True)

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           6
# month             0
# day_of_week       0
# duration          7
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64

# %%
df[df['contact'].isnull()]
# Out:
#          age         job  marital          education  default housing loan  \
# 41188   25.0     student   single        high.school       no      no   no
# 41189  103.0  technician  married        high.school       no      no    n
# 41190   29.0  technician   single              Basic       no     yes    n
# 41191   44.0    services  married        high.school  unknown     yes    y
# 41195    2.0   housemaid  married              Basic  unknown      no    n
# 41196    3.0      admin.   single  university.degree  unknown     yes    y
#
#       contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 41188     NaN   may         fri  ...         4    999         0  nonexistent
# 41189     NaN   aug         fri  ...         1    999         0  nonexistent
# 41190     NaN   may         mon  ...         1    999         0  nonexistent
# 41191     NaN   aug         fri  ...         1    999         0  nonexistent
# ...

# %%
modeContact=df.contact.mode()[0]
print(modeContact)
# Out:
# cellular

# %%
df.fillna(modeContact,inplace=True)

# %%
df.isna().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp_var_rate      0
# cons_price_idx    0
# cons_conf_idx     0
# euribor3m         0
# nr_employed       0
# y                 0
# dtype: int64
